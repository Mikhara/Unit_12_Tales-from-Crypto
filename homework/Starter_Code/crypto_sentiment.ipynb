# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/mikhararamsing/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("news_api")

# %%
# Create a newsapi client
from newsapi.newsapi_client import NewsApiClient
newsapi = NewsApiClient(api_key=api_key)

# %% [markdown]
# ### Note the free news api only pulls 20 articles per a page and for a total of 5 pages. Hence had to pull 5 times and join into 1 df with 100 articles.

# %%
# Fetch the Bitcoin news articles
btc_articles_1 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy", page = 1)['articles'])
btc_articles_2 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy", page = 2)['articles'])
btc_articles_3 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy", page = 3)['articles'])
btc_articles_4 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy", page = 4)['articles'])
btc_articles_5 = pd.DataFrame(newsapi.get_everything(q="bitcoin", language="en", sort_by="relevancy", page = 5)['articles'])

# %%
btc_articles = pd.concat([btc_articles_1, btc_articles_2, btc_articles_3, btc_articles_4, btc_articles_5])

# %%
btc_articles.head()
# Out:
#                                    source  \
# 0  {'id': 'engadget', 'name': 'Engadget'}
# 1     {'id': None, 'name': 'Gizmodo.com'}
# 2  {'id': 'mashable', 'name': 'Mashable'}
# 3  {'id': 'bbc-news', 'name': 'BBC News'}
# 4     {'id': None, 'name': 'Gizmodo.com'}
#
#                                               author  \
# 0  https://www.engadget.com/about/editors/saqib-shah
# 1                                         Matt Novak
# 2                                     Stan Schroeder
# 3                   https://www.facebook.com/bbcnews
# 4                                      Alyse Stanley
#
#                                                title  \
# 0  El Salvador becomes the first country to appro...
# 1  El Salvador Becomes First Country to Recognize...
# 2  Elon Musk says Tesla will resume Bitcoin purch...
# 3  Bitcoin: El Salvador makes cryptocurrency lega...
# 4  Miami's Bitcoin Conference May Be the Latest C...
#
#                                          description  \
# 0  El Salvador has voted to adopt Bitcoin as lega...
# 1  El Salvador has become the first country in th...
# 2  It's all about clean energy, it seems. \nElon ...
# 3  It is the first country in the world to make t...
# 4  Several crypto fans that descended on Miami, F...
#
#                                                  url  \
# 0  https://www.engadget.com/el-salvador-bitcoin-l...
# 1  https://gizmodo.com/el-salvador-becomes-first-...
# 2  https://mashable.com/article/tesla-bitcoin-pur...
# 3  https://www.bbc.co.uk/news/world-latin-america...
# 4  https://gizmodo.com/miamis-bitcoin-conference-...
#
#                                           urlToImage           publishedAt  \
# 0  https://s.yimg.com/os/creatr-uploaded-images/2...  2021-06-09T12:04:40Z
# 1  https://i.kinja-img.com/gawker-media/image/upl...  2021-06-09T10:00:00Z
# 2  https://mondrian.mashable.com/2021%252F06%252F...  2021-06-14T07:15:49Z
# 3  https://ichef.bbci.co.uk/news/1024/branded_new...  2021-06-09T08:27:58Z
# 4  https://i.kinja-img.com/gawker-media/image/upl...  2021-06-11T00:45:00Z
#
#                                              content
# 0  El Salvador's President Nayib Bukele has made ...
# 1  El Salvador has become the first country in th...
# 2  It's all about clean energy, it seems. \r\nElo...
# 3  image captionThe move means bitcoin will be ac...
# 4  Several crypto fans that descended on Miami, F...

# %%
# Fetch the Ethereum news articles
eth_articles_1 = pd.DataFrame(newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy", page = 1)['articles'])
eth_articles_2 = pd.DataFrame(newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy", page = 2)['articles'])
eth_articles_3 = pd.DataFrame(newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy", page = 3)['articles'])
eth_articles_4 = pd.DataFrame(newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy", page = 4)['articles'])
eth_articles_5 = pd.DataFrame(newsapi.get_everything(q="ethereum", language="en", sort_by="relevancy", page = 5)['articles'])

# %%
eth_articles = pd.concat([eth_articles_1, eth_articles_2, eth_articles_3, eth_articles_4, eth_articles_5])

# %%
eth_articles.head()
# Out:
#                                    source                   author  \
# 0  {'id': 'mashable', 'name': 'Mashable'}             Joseph Green
# 1  {'id': 'mashable', 'name': 'Mashable'}               Tim Marcin
# 2    {'id': 'reuters', 'name': 'Reuters'}                  Reuters
# 3    {'id': None, 'name': 'Entrepreneur'}  Entrepreneur en Español
# 4    {'id': None, 'name': 'Slashdot.org'}                   BeauHD
#
#                                                title  \
# 0  This blockchain development course bundle is o...
# 1               Classic memes that have sold as NFTs
# 2  Ethereum extends gains to rise 8%; bitcoin fir...
# 3  Ethereum creator Vitalik Buterin made more tha...
# 4  Norton 360 Antivirus Now Lets You Mine Ethereu...
#
#                                          description  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  Cryptocurrency Ethereum extended gains to rise...
# 3  Ethereum billionaire founder Vitalik Buterin b...
# 4  NortonLifelock has added the ability to mine E...
#
#                                                  url  \
# 0  https://mashable.com/uk/shopping/june-17-crypt...
# 1  https://mashable.com/article/classic-memes-sol...
# 2  https://www.reuters.com/technology/ethereum-ri...
# 3        https://www.entrepreneur.com/article/374264
# 4  https://slashdot.org/story/21/06/03/0358213/no...
#
#                                           urlToImage           publishedAt  \
# 0  https://mondrian.mashable.com/2021%252F06%252F...  2021-06-17T04:05:00Z
# 1  https://mondrian.mashable.com/2021%252F06%252F...  2021-06-20T19:28:07Z
# 2  https://www.reuters.com/resizer/yeaYVdBQ4_EGCb...  2021-05-31T12:17:00Z
# 3  https://assets.entrepreneur.com/content/3x2/20...  2021-06-10T19:12:00Z
# 4        https://a.fsdn.com/sd/topics/bitcoin_64.png  2021-06-03T10:00:00Z
#
#                                              content
# 0  TL;DR: The Cryptocurrency with Ethereum and So...
# 1  It wasn't long ago that your average person ha...
# 2  A representation of virtual currency Ethereum ...
# 3  This article was translated from our Spanish e...
# 4  This new mining feature is called 'Norton Cryp...

# %%
btc_articles['content']
# Out:
# 0     El Salvador's President Nayib Bukele has made ...
# 1     El Salvador has become the first country in th...
# 2     It's all about clean energy, it seems. \r\nElo...
# 3     image captionThe move means bitcoin will be ac...
# 4     Several crypto fans that descended on Miami, F...
#                             ...
# 15    A logo is pictured on Sotheby's in Geneva, Swi...
# 16    NEW YORK, June 21 (Reuters) - The dollar retre...
# 17    Banks must set aside enough capital to cover l...
# 18    LONDON, June 21 (Reuters) - The dollar held on...
# 19    Blockchain technology company Blockstream Mini...
# Name: content, Length: 100, dtype: object

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []

for content in btc_articles['content']:
    sentiment = analyzer.polarity_scores(content)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]

    btc_sentiments.append({
        "text": content,
        #"date": date,
        "compound": compound,
        "positive": pos,
        "negative": neg,
        "neutral": neu

    })

# %%
# Create DataFrame
btc_df = pd.DataFrame(btc_sentiments)

#Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
btc_df = btc_df[cols]

btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral
# 0       0.0    0.718
# 1       0.0    0.957
# 2       0.0    0.831
# 3       0.0    0.940
# 4       0.0    0.893

# %%
btc_df.shape
# Out:
# (100, 6)

# %%
eth_articles['content'].head()
# Out:
# 0    TL;DR: The Cryptocurrency with Ethereum and So...
# 1    It wasn't long ago that your average person ha...
# 2    A representation of virtual currency Ethereum ...
# 3    This article was translated from our Spanish e...
# 4    This new mining feature is called 'Norton Cryp...
# Name: content, dtype: object

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sentiments = []

eth_sentiments = []

for content in eth_articles['content']:
    sentiment = analyzer.polarity_scores(content)
    compound = sentiment["compound"]
    pos = sentiment["pos"]
    neu = sentiment["neu"]
    neg = sentiment["neg"]

    eth_sentiments.append({
        "text": content,
        #"date": date,
        "compound": compound,
        "positive": pos,
        "negative": neg,
        "neutral": neu

    })

# %%
# Create DataFrame
eth_df = pd.DataFrame(eth_sentiments)

# Reorder DataFrame columns
cols = ["text", "compound", "positive", "negative", "neutral"]
eth_df = eth_df[cols]

eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...     0.000       0.0
# 1  It wasn't long ago that your average person ha...    -0.296       0.0
# 2  A representation of virtual currency Ethereum ...     0.000       0.0
# 3  This article was translated from our Spanish e...    -0.340       0.0
# 4  This new mining feature is called 'Norton Cryp...     0.000       0.0
#
#    negative  neutral
# 0     0.000    1.000
# 1     0.061    0.939
# 2     0.000    1.000
# 3     0.066    0.934
# 4     0.000    1.000

# %%
# Describe the Bitcoin Sentiment
btc_df.describe()
# Out:
#          compound    positive    negative     neutral
# count  100.000000  100.000000  100.000000  100.000000
# mean     0.049785    0.047230    0.031460    0.921320
# std      0.359110    0.063429    0.045438    0.072366
# min     -0.778300    0.000000    0.000000    0.718000
# 25%     -0.238025    0.000000    0.000000    0.871000
# 50%      0.000000    0.000000    0.000000    0.927000
# 75%      0.323650    0.083250    0.070000    1.000000
# max      0.840200    0.282000    0.178000    1.000000

# %%
# Describe the Ethereum Sentiment
eth_df.describe()
# Out:
#          compound   positive    negative     neutral
# count  100.000000  100.00000  100.000000  100.000000
# mean     0.138684    0.05918    0.024950    0.915890
# std      0.359255    0.06878    0.042954    0.077195
# min     -0.750600    0.00000    0.000000    0.655000
# 25%      0.000000    0.00000    0.000000    0.879000
# 50%      0.115350    0.05600    0.000000    0.927000
# 75%      0.401900    0.09250    0.060000    1.000000
# max      0.848100    0.29000    0.262000    1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Interestingly, when we have a sample size of 20, Bitcoin has highest positive mean score of 0.07 vs Ethereum of 0.04. Yet, with a sample size of 100, we see Ethereum has the larger mean positive score of 0.06 vs Bitcoin at 0.05.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum has the far largest mean compound score of 0.14 vs Bitcoin at 0.05.
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum and Bitcoin had very similar max positive scors of 0.29 and 0.28 respectively, wih Ethereum's being higher.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
#nltk.download()

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
btc_articles['content']
# Out:
# 0     El Salvador's President Nayib Bukele has made ...
# 1     El Salvador has become the first country in th...
# 2     It's all about clean energy, it seems. \r\nElo...
# 3     image captionThe move means bitcoin will be ac...
# 4     Several crypto fans that descended on Miami, F...
#                             ...
# 15    A logo is pictured on Sotheby's in Geneva, Swi...
# 16    NEW YORK, June 21 (Reuters) - The dollar retre...
# 17    Banks must set aside enough capital to cover l...
# 18    LONDON, June 21 (Reuters) - The dollar held on...
# 19    Blockchain technology company Blockstream Mini...
# Name: content, Length: 100, dtype: object

# %%
big_string = " ".join(btc_articles['content'].astype(str))

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords

sentence = sent_tokenize(big_string)
words = word_tokenize(big_string)
sw = set(stopwords.words('english'))
first_result = [word.lower() for word in words if word.lower() not in sw]
#print (first_result)

# %%
# Expand the default stopwords list if necessary
#sw_addon = {}
#second_result = [word.lower() for word in words if word.lower() not in sw.union(sw_addon)]

# %% [markdown]
# Was not necessary to add any more stopwords

# %%
# Complete the tokenizer function
def tokenizer(text):
    # Remove the stop words
    sw = set(stopwords.words('english'))
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
    # Convert the words to lowercase
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
btc_processed = btc_articles['content'].apply(tokenizer)
print(btc_processed)
# Out:
# 0     [el, salvadors, president, nayib, bukele, ha, ...
# 1     [el, salvador, ha, become, first, country, wor...
# 2     [clean, energy, seemselon, musk, tesla, caused...
# 3     [image, captionthe, move, mean, bitcoin, accep...
# 4     [several, crypto, fan, descended, miami, flori...
#                             ...
# 15    [logo, pictured, sothebys, geneva, switzerland...
# 16    [new, york, june, reuters, dollar, retreated, ...
# 17    [banks, must, set, aside, enough, capital, cov...
# 18    [london, june, reuters, dollar, held, previous...
# 19    [blockchain, technology, company, blockstream,...
# Name: content, Length: 100, dtype: object

# %%
type(btc_processed)
# Out:
# pandas.core.series.Series

# %%
# Create a new tokens column for Bitcoin
btc_df['tokens']= btc_processed.values
btc_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  El Salvador's President Nayib Bukele has made ...    0.8402     0.282
# 1  El Salvador has become the first country in th...    0.1280     0.043
# 2  It's all about clean energy, it seems. \r\nElo...    0.6908     0.169
# 3  image captionThe move means bitcoin will be ac...    0.2732     0.060
# 4  Several crypto fans that descended on Miami, F...    0.5574     0.107
#
#    negative  neutral                                             tokens
# 0       0.0    0.718  [el, salvadors, president, nayib, bukele, ha, ...
# 1       0.0    0.957  [el, salvador, ha, become, first, country, wor...
# 2       0.0    0.831  [clean, energy, seemselon, musk, tesla, caused...
# 3       0.0    0.940  [image, captionthe, move, mean, bitcoin, accep...
# 4       0.0    0.893  [several, crypto, fan, descended, miami, flori...

# %%
eth_processed = eth_articles['content'].apply(tokenizer)
print(eth_processed)
# Out:
# 0     [tldr, cryptocurrency, ethereum, solidity, blo...
# 1     [wasnt, long, ago, average, person, clue, nft,...
# 2     [representation, virtual, currency, ethereum, ...
# 3     [article, wa, translated, spanish, edition, us...
# 4     [new, mining, feature, called, norton, crypto,...
#                             ...
# 15    [world, equity, set, post, fourth, consecutive...
# 16    [sign, indicating, digital, yuan, also, referr...
# 17    [heres, something, different, ethereumbitcoin,...
# 18    [losses, british, fintech, firm, revolut, near...
# 19    [digital, asset, mining, shorthand, proof, wor...
# Name: content, Length: 100, dtype: object

# %%
# Create a new tokens column for Ethereum
eth_df['tokens']= eth_processed.values
eth_df.head()
# Out:
#                                                 text  compound  positive  \
# 0  TL;DR: The Cryptocurrency with Ethereum and So...     0.000       0.0
# 1  It wasn't long ago that your average person ha...    -0.296       0.0
# 2  A representation of virtual currency Ethereum ...     0.000       0.0
# 3  This article was translated from our Spanish e...    -0.340       0.0
# 4  This new mining feature is called 'Norton Cryp...     0.000       0.0
#
#    negative  neutral                                             tokens
# 0     0.000    1.000  [tldr, cryptocurrency, ethereum, solidity, blo...
# 1     0.061    0.939  [wasnt, long, ago, average, person, clue, nft,...
# 2     0.000    1.000  [representation, virtual, currency, ethereum, ...
# 3     0.066    0.934  [article, wa, translated, spanish, edition, us...
# 4     0.000    1.000  [new, mining, feature, called, norton, crypto,...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# BTC
big_processed_string = tokenizer(big_string)

# %%
# Generate the Bitcoin N-grams where N=2
btc_counts = Counter(ngrams(big_processed_string, n=2))
print(dict(btc_counts))
# Out:
# {('el', 'salvadors'): 8, ('salvadors', 'president'): 2, ('president', 'nayib'): 7, ('nayib', 'bukele'): 6, ('bukele', 'ha'): 1, ('ha', 'made'): 1, ('made', 'good'): 1, ('good', 'promise'): 1, ('promise', 'adopt'): 1, ('adopt', 'bitcoin'): 3, ('bitcoin', 'legal'): 12, ('legal', 'tender'): 11, ('tender', 'officials'): 1, ('officials', 'central'): 1, ('central', 'american'): 3, ('american', 'country'): 1, ('country', 'congress'): 1, ('congress', 'voted'): 1, ('voted', 'accept'): 1, ('accept', 'cryptocurrency'): 1, ('cryptocurrency', 'majori'): 1, ('majori', 'char'): 1, ('char', 'el'): 5, ('el', 'salvador'): 10, ('salvador', 'ha'): 5, ('ha', 'become'): 5, ('become', 'first'): 5, ('first', 'country'): 6, ('country', 'world'): 6, ('world', 'recognize'): 1, ('recognize', 'cryptocurrency'): 1, ('cryptocurrency', 'bitcoin'): 4, ('legal', 'currency'): 1, ('currency', 'according'): 1, ('according', 'president'): 1, ('bukele', 'tweet'): 1, ('tweet', 'wednesday'): 1, ('wednesday', 'citizens'): 1, ('citizens', 'able'): 1, ('able', 'char'): 1, ('char', 'clean'): 1, ('clean', 'energy'): 2, ('energy', 'seemselon'): 1, ('seemselon', 'musk'): 1, ('musk', 'tesla'): 1, ('tesla', 'caused'): 1, ('caused', 'ripple'): 1, ('ripple', 'cryptocurrency'): 1, ('cryptocurrency', 'market'): 1, ('market', 'past'): 1, ('past', 'month'): 1, ('month', 'first'): 1, ('first', 'announcing'): 1, ('announcing', 'tesla'): 1, ('tesla', 'bought'): 1, ('bought', 'billion'): 1, ('billion', 'worth'): 1, ('worth', 'bitcoi'): 1, ('bitcoi', 'char'): 2, ('char', 'image'): 1, ('image', 'captionthe'): 1, ('captionthe', 'move'): 1, ('move', 'mean'): 1, ('mean', 'bitcoin'): 1, ('bitcoin', 'accepted'): 1, ('accepted', 'everywhere'): 1, ('everywhere', 'good'): 1, ('good', 'service'): 1, ('service', 'alongside'): 1, ('alongside', 'us'): 2, ('us', 'dollarel'): 1, ('dollarel', 'salvador'): 1, ('world', 'officially'): 1, ('officially', 'classify'): 1, ('classify', 'bitcoin'): 2, ('bitcoin', 'char'): 1, ('char', 'several'): 1, ('several', 'crypto'): 1, ('crypto', 'fan'): 1, ('fan', 'descended'): 1, ('descended', 'miami'): 1, ('miami', 'florida'): 1, ('florida', 'last'): 1, ('last', 'weekend'): 1, ('weekend', 'largest'): 1, ('largest', 'bitcoin'): 1, ('bitcoin', 'conference'): 1, ('conference', 'history'): 1, ('history', 'saying'): 1, ('saying', 'theyve'): 1, ('theyve', 'tested'): 1, ('tested', 'positive'): 1, ('positive', 'covid'): 1, ('covid', 'larry'): 1, ('larry', 'cermak'): 1, ('cermak', 'research'): 1, ('research', 'director'): 1, ('director', 'char'): 1, ('char', 'hello'): 2, ('hello', 'friend'): 1, ('friend', 'welcome'): 1, ('welcome', 'back'): 2, ('back', 'week'): 1, ('week', 'reviewlast'): 1, ('reviewlast', 'week'): 1, ('week', 'wrote'): 1, ('wrote', 'tech'): 1, ('tech', 'taking'): 1, ('taking', 'disney'): 1, ('disney', 'week'): 1, ('week', 'im'): 1, ('im', 'talking'): 1, ('talking', 'search'): 1, ('search', 'new'): 1, ('new', 'crypto'): 1, ('crypto', 'messiahif'): 1, ('messiahif', 'youre'): 1, ('youre', 'reading'): 1, ('reading', 'tec'): 1, ('tec', 'char'): 1, ('char', 'maryann'): 1, ('maryann', 'russonbusiness'): 1, ('russonbusiness', 'reporter'): 1, ('reporter', 'bbc'): 1, ('bbc', 'newsimage'): 1, ('newsimage', 'copyrightgetty'): 1, ('copyrightgetty', 'imagesformer'): 1, ('imagesformer', 'us'): 1, ('us', 'president'): 1, ('president', 'donald'): 1, ('donald', 'trump'): 1, ('trump', 'ha'): 1, ('ha', 'told'): 1, ('told', 'fox'): 1, ('fox', 'business'): 1, ('business', 'see'): 1, ('see', 'bitcoin'): 1, ('bitcoin', 'scam'): 1, ('scam', 'affecting'): 1, ('affecting', 'value'): 1, ('value', 'us'): 1, ('us', 'dolla'): 1, ('dolla', 'char'): 1, ('char', 'san'): 2, ('san', 'salvador'): 3, ('salvador', 'june'): 4, ('june', 'reuters'): 22, ('reuters', 'el'): 7, ('salvador', 'replace'): 2, ('replace', 'us'): 2, ('us', 'dollar'): 4, ('dollar', 'bitcoin'): 2, ('tender', 'finance'): 2, ('finance', 'minister'): 2, ('minister', 'alejandro'): 2, ('alejandro', 'zelaya'): 2, ('zelaya', 'said'): 2, ...

# %%
big_string_eth = " ".join(eth_articles['content'].astype(str))

# %%
# ETH
big_processed_string_eth = tokenizer(big_string_eth)

# %%
# Generate the Ethereum N-grams where N=2
eth_counts = Counter(ngrams(big_processed_string_eth, n=2))
print(dict(eth_counts))
# Out:
# {('tldr', 'cryptocurrency'): 2, ('cryptocurrency', 'ethereum'): 3, ('ethereum', 'solidity'): 2, ('solidity', 'blockchain'): 2, ('blockchain', 'developer'): 2, ('developer', 'bundle'): 2, ('bundle', 'sale'): 1, ('sale', 'june'): 1, ('june', 'saving'): 1, ('saving', 'list'): 1, ('list', 'priceis'): 1, ('priceis', 'everyone'): 1, ('everyone', 'know'): 1, ('know', 'investing'): 1, ('investing', 'cryptocurrency'): 1, ('cryptocurrency', 'char'): 8, ('char', 'wasnt'): 1, ('wasnt', 'long'): 2, ('long', 'ago'): 2, ('ago', 'average'): 1, ('average', 'person'): 1, ('person', 'clue'): 1, ('clue', 'nft'): 1, ('nft', 'wa'): 1, ('wa', 'nowadays'): 1, ('nowadays', 'theyre'): 1, ('theyre', 'making'): 1, ('making', 'headline'): 1, ('headline', 'selling'): 1, ('selling', 'hundred'): 1, ('hundred', 'thousand'): 1, ('thousand', 'buck'): 1, ('buck', 'predictably'): 1, ('predictably', 'folk'): 1, ('folk', 'learning'): 1, ('learning', 'nfts'): 1, ('nfts', 'char'): 1, ('char', 'representation'): 7, ('representation', 'virtual'): 6, ('virtual', 'currency'): 4, ('currency', 'ethereum'): 1, ('ethereum', 'seen'): 2, ('seen', 'front'): 3, ('front', 'stock'): 3, ('stock', 'graph'): 3, ('graph', 'illustration'): 3, ('illustration', 'taken'): 7, ('taken', 'february'): 1, ('february', 'reutersdado'): 2, ('reutersdado', 'ruvicillustrationfile'): 2, ('ruvicillustrationfile', 'photocryptocurrency'): 1, ('photocryptocurrency', 'ethereum'): 1, ('ethereum', 'extende'): 1, ('extende', 'char'): 1, ('char', 'article'): 4, ('article', 'wa'): 4, ('wa', 'translated'): 4, ('translated', 'spanish'): 4, ('spanish', 'edition'): 4, ('edition', 'using'): 4, ('using', 'ai'): 4, ('ai', 'technology'): 4, ('technology', 'errors'): 4, ('errors', 'may'): 4, ('may', 'exist'): 4, ('exist', 'due'): 4, ('due', 'processlast'): 1, ('processlast', 'may'): 1, ('may', 'vitalik'): 1, ('vitalik', 'buterin'): 1, ('buterin', 'became'): 1, ('became', 'youngest'): 1, ('youngest', 'billionaire'): 1, ('billionaire', 'world'): 1, ('world', 'ye'): 1, ('ye', 'char'): 1, ('char', 'new'): 5, ('new', 'mining'): 1, ('mining', 'feature'): 1, ('feature', 'called'): 1, ('called', 'norton'): 1, ('norton', 'crypto'): 2, ('crypto', 'rolling'): 1, ('rolling', 'tomorrow'): 1, ('tomorrow', 'norton'): 1, ('norton', 'user'): 1, ('user', 'enrolled'): 1, ('enrolled', 'nortons'): 1, ('nortons', 'early'): 1, ('early', 'adopter'): 1, ('adopter', 'program'): 1, ('program', 'norton'): 1, ('crypto', 'enabled'): 1, ('enabled', 'software'): 1, ('software', 'use'): 1, ('use', 'char'): 1, ('char', 'opinions'): 6, ('opinions', 'expressed'): 6, ('expressed', 'entrepreneur'): 6, ('entrepreneur', 'contributor'): 6, ('contributor', 'ownlaunched'): 1, ('ownlaunched', 'march'): 1, ('march', 'racked'): 1, ('racked', 'one'): 1, ('one', 'million'): 1, ('million', 'user'): 1, ('user', 'already'): 1, ('already', 'safemoon'): 1, ('safemoon', 'blockchainbased'): 1, ('blockchainbased', 'cryptocurrencysimilar'): 1, ('cryptocurrencysimilar', 'char'): 1, ('char', 'cryptopunks'): 1, ('cryptopunks', 'represent'): 1, ('represent', 'historically'): 1, ('historically', 'relevant'): 1, ('relevant', 'narrative'): 1, ('narrative', 'upon'): 1, ('upon', 'value'): 1, ('value', 'could'): 1, ('could', 'conceivably'): 1, ('conceivably', 'live'): 1, ('live', 'decade'): 1, ('decade', 'within'): 1, ('within', 'expanding'): 1, ('expanding', 'catalogue'): 1, ('catalogue', 'raisonn'): 1, ('raisonn', 'ill'): 1, ('ill', 'damned'): 1, ('damned', 'im'): 1, ('im', 'counting'): 1, ('counting', 'jacks'): 1, ('jacks', 'tweet'): 1, ('tweet', 'char'): 2, ('char', 'cristina'): 1, ('cristina', 'criddletechnology'): 1, ('criddletechnology', 'reporterimage'): 1, ('reporterimage', 'captionnft'): 1, ('captionnft', 'kim'): 1, ('kim', 'catdarshians'): 1, ('catdarshians', 'fur'): 1, ('fur', 'dotted'): 1, ('dotted', 'diamond'): 1, ('diamond', 'symbol'): 1, ('symbol', 'cryptocurrency'): 1, ('cryptocurrency', 'ethereumthe'): 1, ('ethereumthe', 'hype'): 1, ('hype', 'surrounding'): 1, ('sur ...

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

def word_counter(corpus): 
    # Combine all articles in corpus into one large string
    big_string = ' '.join(corpus)
    processed = tokenizer(big_string)
    top_10 = dict(Counter(processed).most_common(10))
    return pd.DataFrame(list(top_10.items()), columns=['word', 'count'])

# %%
# Use token_count to get the top 10 words for Bitcoin
word_counts = Counter(big_processed_string)
print(dict(word_counts.most_common(10)))
# Out:
# {'char': 97, 'bitcoin': 93, 'reuters': 54, 'june': 35, 'cryptocurrency': 32, 'el': 22, 'world': 22, 'monday': 19, 'illustration': 17, 'seen': 17}

# %%
# Use token_count to get the top 10 words for Ethereum
word_counts = Counter(big_processed_string_eth)
print(dict(word_counts.most_common(10)))
# Out:
# {'char': 99, 'bitcoin': 38, 'reuters': 31, 'cryptocurrency': 27, 'world': 24, 'june': 21, 'ethereum': 18, 'digital': 15, 'cryptocurrencies': 15, 'seen': 14}

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
input_words = tokenizer(big_string)

wc = WordCloud().generate(input_words)
plt.imshow(wc)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-110-72f507da38af> in <module>
#       2 input_words = tokenizer(big_string)
#       3
# ----> 4 wc = WordCloud().generate(input_words)
#       5 plt.imshow(wc)
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/site-packages/wordcloud/wordcloud.py in process_text(self, text)
#     573         regexp = self.regexp if self.regexp is not None else pattern
#     574
# --> 575         words = re.findall(regexp, text, flags)
#     576         # remove 's
#     577         words = [word[:-2] if word.lower().endswith("'s") else word
#
# ~/opt/anaconda3/envs/dev/lib/python3.9/re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Generate the Ethereum word cloud
# YOUR CODE HERE!

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en_core_web_sm==2.3.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 4.1 MB/s eta 0:00:01
# Requirement already satisfied: spacy<2.4.0,>=2.3.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from en_core_web_sm==2.3.1) (2.3.5)
# Requirement already satisfied: numpy>=1.15.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.19.2)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: thinc<7.5.0,>=7.4.1 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (7.4.5)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (3.0.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.61.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.8.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.25.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (0.7.4)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.0.0)
# Requirement already satisfied: setuptools in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (52.0.0.post20210125)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (1.26.5)
# Requirement already satisfied: idna<3,>=2.5 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/mikhararamsing/opt/anaconda3/envs/dev/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<2.4.0,>=2.3.0->en_core_web_sm==2.3.1) (4.0.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
#print (big_string)

# %%
# Run the NER processor on all of the text
doc_btc = nlp(big_string)

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
displacy.render(doc_btc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador's
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayib Bukele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has made good on his promise to adopt
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  as legal tender. Officials in the
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Central American
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  country's
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  voted to accept the cryptocurrency by a majori… [+1414 chars]
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has become the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country in the world to recognize the cryptocurrency bitcoin as legal currency, according to President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nayib Bukele
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in a tweet on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Citizens
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br>Elon Musk and
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  caused ripples in the cryptocurrency market in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past few months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  by announcing that
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  had bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $1.5 billion
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  worth of bitcoi… [+2508 chars] image captionThe move means bitcoin will be accepted everywhere for goods and services, alongside the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     El Salvador
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  has become the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  country in the world to officially classify
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bitcoin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  a… [+2233 chars] Several crypto fans that descended on
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Miami
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Florida
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last weekend
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; ma

# %%
# List all Entities
print([ent.text for ent in doc_btc.ents if ent.label_ == 'GPE'])
# Out:
# ["El Salvador's", 'Bitcoin', 'El Salvador', 'US', 'El Salvador', 'Bitcoin', 'Miami', 'Florida', 'US', 'Bitcoin', 'US', 'SAN SALVADOR', 'El Salvador', 'U.S.', 'LONDON', 'El Salvador', 'LONDON', 'El Salvador', 'Bitcoin', 'El Salvador', 'U.S.', 'US', 'MarketBeatWhen', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'China', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'China', 'bitcoin', 'Sichuan', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Gruenheide', 'Berlin', 'Germany', 'Bitcoin', 'Amundi', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'China', 'Miami', "El Salvador's", 'US', 'bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'US', 'Bitcoin', 'NEW YORK', 'Bitcoin', 'Dubai', 'Bitcoin', 'U.S.', 'Bitcoin', 'Los Angeles', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', "El Salvador's", 'El Salvadoran', 'El Zonte', 'NEW YORK', 'Bitcoin', 'China', 'China', 'Bitcoin', 'El Salvador', 'Paris', 'MEXICO CITY', 'bitcoin', 'LONDON', 'Bitcoin', 'China', 'Bitcoin', 'U.S.', 'Bitcoin ATM', 'San Salvador', 'El Salvador', 'NEW YORK', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Chiltiupan', 'El Salvador', 'China', 'Yunnan province', 'Switzerland', 'Bitcoin', 'NEW YORK', 'Bitcoin', 'El Zonte', 'Bitcoin', 'El Salvador', 'Bitcoin', 'China', 'New York', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'WASHINGTON', 'U.S.', 'China', 'Bitcoin', 'Bitcoin', 'China', 'Bitcoin', 'U.S.', 'AI', 'El Salvador', 'Bitcoin', 'LONDON', 'NEW YORK', 'Bitcoin', 'KONG', 'Bitcoin', 'HONG KONG', 'Bitcoin', 'Chinas', 'LONDON', 'China', 'U.S.', 'SAN SALVADOR', "El Salvador's", 'Geneva', 'Switzerland', 'NEW YORK', 'LONDON', 'China']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
#print (big_string_eth)

# %%
# Run the NER processor on all of the text
doc_eth = nlp(big_string_eth)

# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">TL;DR: The Cryptocurrency with Ethereum and Solidity Blockchain Developer Bundle is on sale for £
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     21.25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">MONEY</span>
# </mark>
#  as of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June 17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , saving you
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     97%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# </br>Is everyone you know investing in cryptocurrency? … [+949 chars] It wasn't long ago that your average person had no clue what an
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NFT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  was. Nowadays, they're making headlines for selling for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hundreds of thousands
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of bucks. Predictably, folks are learning about NFTs … [+3056 chars] A representation of virtual currency Ethereum is seen in front of a stock graph in this illustration taken
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February 19, 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REUTERS/
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# Dado Ruvic/Illustration/File PhotoCryptocurrency Ethereum extende… [+1099 chars] This article was translated from our
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  edition using
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# </br>
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Last May
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VitaliK Buterin
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  became the youngest billionaire in the world at just 27 ye… [+2422 chars] This new mining feature is called '
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton Crypto'
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and will be rolling out
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tomorrow
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     360
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users enrolled in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# 's early adopter program. When
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Norton Crypto
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </br>Launched in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and having racked up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     more than one million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  users already,
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SafeMoon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  is a blockchain-based cryptocurrency similar … [+3939 chars]
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CryptoPunks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# <

# %%
# List all Entities
print([ent.text for ent in doc_eth.ents if ent.label_ == 'GPE'])
# Out:
# ['AI', 'China', 'China', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'NEW YORK', 'Bitcoin', 'NEW YORK', 'Bitcoin', 'Bitcoin', 'China', 'Bitcoin', 'crypto', 'Bitcoin', 'Bitcoin', 'Dash', 'Bitcoin', 'Bitcoin', 'Dash', 'YORK', 'Bitcoin', 'Bitcoin', 'Bitcoin', 'Dash', 'Figma', 'Bitcoin', 'UK', 'bitcoin', 'Bitcoin', 'Dogecoin', 'Bitcoin', 'Dash', 'London', 'Britain', 'Bitcoin', 'Dash', 'Bitcoin', 'AI', 'DueIt', 'LONDON', 'London', 'AI', 'AI', 'bitcoin', 'LONDON', 'NEW YORK', 'Bitcoin', 'Bitcoin', 'US', 'Bitcoin', 'Ethereum', 'Bitcoin', 'LONDON', 'LONDON', 'U.S.', 'Shanghai', 'China', 'Bitcoin', 'Bitcoin']

# %% [markdown]
# ---
